# %%
import os
from dotenv import load_dotenv
from anthropic import Anthropic
load_dotenv()

print("Key loaded:", os.environ["ANTHROPIC_API_KEY"][:8], "...")
# Out:
# Key loaded: sk-ant-a ...

# %%
client = Anthropic()
resp = client.messages.create(
         model="claude-haiku-4-5-20251001",
         max_tokens=1024,
         system="You are a concise physics tutor.",
         messages=[
             {"role": "user", "content": "What is the binding energy per nucleon for iron-56, and why is it the peak of the curve?"},
         ],
 )
print(resp.content[0].text)
# Out:
# # Binding Energy Per Nucleon for Iron-56
#
# ## The Value
# Iron-56 has a binding energy per nucleon of approximately **8.8 MeV/nucleon**, which is the highest value on the binding energy curve.
#
# ## Why It's the Peak
#
# The binding energy per nucleon peaks at Fe-56 due to competing nuclear forces:
#
# ### 1. **Strong Nuclear Force (attractive)**
# - Dominates at short ranges
# - Holds nucleons together
# - More nucleons → more binding energy initially
#
# ### 2. **Electrostatic Repulsion (repulsive)**
# - Protons repel each other
# - Increases with more protons
# - Becomes significant for heavier nuclei
#
# ### 3. **The Balance at Fe-56**
# - **Light nuclei** (A < 56): Can add nucleons and increase binding energy
# - **Fe-56**: Optimal balance—strong force maximized, repulsion still manageable
# - **Heavy nuclei** (A > 56): Coulomb repulsion dominates; binding energy per nucleon *decreases*
#
# ## Significance
# This is why:
# - **Fusion** of light nuclei releases energy (moving toward Fe-56)
# - **Fission** of heavy nuclei releases energy (moving toward Fe-56)
# - Fe-56 is the most stable nucleus per nucleon
#
# Iron-56 represents the "sweet spot" where the nucleus is most tightly bound.

# %%
# !printf '.env\n' > .gitignore

# %%
# Out:
# remote: Permission to Thanh-Ly66235/phys7440-env.git denied to Thanh-Ly66235.
# fatal: unable to access 'https://github.com/Thanh-Ly66235/phys7440-env.git/': The requested URL returned error: 403

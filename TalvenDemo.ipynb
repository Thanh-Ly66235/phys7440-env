# %%
import os
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

print("Key loaded:", os.environ["ANTHROPIC_API_KEY"][:8], "...")
# Out:
# Key loaded: sk-ant-a ...

# %%
client = Anthropic()
resp = client.messages.create(
         model="claude-haiku-4-5-20251001",
         max_tokens=1024,
         system="You are a concise physics tutor.",
         messages=[
             {"role": "user", "content": "What is the binding energy per nucleon for iron-56, and why is it the peak of the curve?"},
         ],
 )
print(resp.content[0].text)
# Out:
# # Binding Energy per Nucleon for Iron-56
#
# **The value:** Iron-56 has a binding energy per nucleon of approximately **8.79 MeV/nucleon** — the highest of any nucleus.
#
# ## Why Fe-56 is at the peak:
#
# The binding energy per nucleon curve peaks at Fe-56 due to competing nuclear forces:
#
# **1. Strong Nuclear Force (favors larger nuclei)**
# - Binds nucleons together very effectively
# - Very short range (~2 fm)
# - Strength increases with more nucleons
#
# **2. Electrostatic Repulsion (favors smaller nuclei)**
# - Protons repel each other
# - Long-range Coulomb force
# - Grows with Z²
#
# **Fe-56 represents the sweet spot** where:
# - Nucleons are tightly bound by the strong force
# - Proton repulsion is minimal (26 protons)
# - The nucleus-to-charge ratio is optimized
#
# ## Nuclear Stability Consequence:
#
# - **Lighter than Fe-56:** Fusion releases energy (nucleons move toward the peak)
# - **Heavier than Fe-56:** Fission releases energy (nucleons move toward the peak)
# - **Fe-56 is most stable** — it requires the most energy per nucleon to disassemble
#
# This is why iron is abundant in the universe and why stellar fusion stops at iron in massive stars.

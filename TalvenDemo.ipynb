# %%
import os
from dotenv import load_dotenv
from anthropic import Anthropic
load_dotenv()

print("Key loaded:", os.environ["ANTHROPIC_API_KEY"][:8], "...")
# Out:
# Key loaded: sk-ant-a ...

# %%
client = Anthropic()
resp = client.messages.create(
         model="claude-haiku-4-5-20251001",
         max_tokens=1024,
         system="You are a concise physics tutor.",
         messages=[
             {"role": "user", "content": "What is the binding energy per nucleon for iron-56, and why is it the peak of the curve?"},
         ],
 )
print(resp.content[0].text)
# Out:
# # Binding Energy Per Nucleon for Iron-56
#
# ## The Value
# **Fe-56 has ~8.79 MeV per nucleon**, which is the highest of all stable nuclei.
#
# ## Why It's the Peak
#
# ### Energy Release Patterns
# - **Light nuclei (A < 56)**: Fusion releases energy because combining them increases binding energy per nucleon
# - **Heavy nuclei (A > 56)**: Fission releases energy because splitting them increases binding energy per nucleon
# - **Fe-56**: The sweet spot where nucleons are most tightly bound
#
# ### Physical Reason
# The binding energy per nucleon results from competing forces:
#
# 1. **Strong nuclear force** (attractive) - dominates at short range, favors larger nuclei
# 2. **Coulomb repulsion** (repulsive) - grows with proton number, favors smaller nuclei
#
# At Fe-56, these forces achieve optimal balance:
# - Nucleus is large enough for maximum strong-force cooperation
# - Coulomb repulsion hasn't yet become prohibitively costly
# - Nucleon packing is most efficient
#
# ### Consequence
# This is why Fe-56 is **the most stable nucleus** - you can't release energy by fusing it or splitting it. In stellar nucleosynthesis, iron marks the limit of energy-releasing fusion in star cores.
